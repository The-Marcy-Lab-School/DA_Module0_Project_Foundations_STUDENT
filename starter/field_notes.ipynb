# %% [markdown]
# # Data Literacy Field Notes
#
# See `../README.md` for the dataset link. Work through this in order: open the raw file first, form a hypothesis about each column, *then* verify it in code. Don't reverse that order.

# %% [markdown]
# ## 1. First look at the raw file
#
# Before writing any code: open the CSV directly (in a text editor, `less`, or `head` in the terminal) and look at the first few rows and the header. Write down what you notice here, in your own words, before you inspect it programmatically.

# %% [markdown]
# _TODO: your raw-file observations here._

# %% [markdown]
# ## 2. Load the data and inspect columns

# %%
# TODO: load the dataset (csv module or pandas, your choice) and print the column names.

# %% [markdown]
# ## 3. Column-by-column data type table
#
# For each column: your inferred data type, and one sentence on how you can tell (not a guess — cite what you actually saw in the data).

# %% [markdown]
# | Column | Inferred type | How I can tell |
# |---|---|---|
# | _TODO_ | _TODO_ | _TODO_ |

# %% [markdown]
# **In your own words:** what's the actual difference between a list/array and a table? (Not a definition you looked up — explain it the way you'd explain it to a friend who's never coded.)

# %% [markdown]
# _TODO_

# %% [markdown]
# ## 4. Structured or unstructured?
#
# State which this dataset is, and why.

# %% [markdown]
# _TODO_

# %% [markdown]
# ## 5. Before you trust this data
#
# List **at least 2** specific things you'd want to know about how this dataset was collected, before trusting any conclusion drawn from it. (Not "is it accurate" in general — name the actual concerns: who collected it, how, what might be missing, what could bias it.)

# %% [markdown]
# 1. _TODO_
# 2. _TODO_

# %% [markdown]
# ## 6. Data-quality question for the source
#
# Take the **most specific and checkable** of the two concerns above, and phrase it as a real question you'd send to the data's source/maintainer. A good test: could they actually answer it with a concrete yes/no or fact — not "is this data good?"

# %% [markdown]
# _TODO_

# %% [markdown]
# ## 7. Something you're actually curious about
#
# Different question from #6 — that one was about checking the data's trustworthiness. This one's about you: what's something you're genuinely curious to explore *using* this data? Be specific.

# %% [markdown]
# _TODO_

# %% [markdown]
# ## 8. AI-literacy reflection
#
# Name **2 concrete risks** of trusting an AI assistant's output about this dataset (or any data question) without checking it yourself. Then state **one specific personal rule** for when you'll double-check an AI-provided fact before relying on it professionally — specific enough that you could actually follow it, not "I'll be careful."

# %% [markdown]
# **Risks:**
# 1. _TODO_
# 2. _TODO_
#
# **My rule:** _TODO_
